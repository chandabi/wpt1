# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
df=pd.DataFrame({
    'Housesize':[1000,1200,1500,1800,2000],
    'price':[50,60,75,90,100]

})
print(df)
x=df[['Housesize']]
y=df['price']
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(xtrain,ytrain)
y_predict=model.predict(xtest)
print(y_predict)
prediction=model.predict([[1600]])
print('predicted value for 1600 sqft is:',prediction)
# Out:
#    Housesize  price
# 0       1000     50
# 1       1200     60
# 2       1500     75
# 3       1800     90
# 4       2000    100
# [60.]
# predicted value for 1600 sqft is: [80.]
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
df=pd.DataFrame({
    'Experience':[10,5,8,8,6],
    'Salary':[10000,25000,15000,12000,30000]

})
print(df)
x=df[['Experience']]
y=df['Salary']
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(xtrain,ytrain)
y_predict=model.predict(xtest)
print(y_predict)
# Out:
#    Experience  Salary
# 0          10   10000
# 1           5   25000
# 2           8   15000
# 3           8   12000
# 4           6   30000
# [31750.]

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
print(df)
df.isnull().sum()
mean=df.mean()
print(mean)
df=df.fillna(mean)
print(df)
print("missing value after replacing :",df.isnull().sum())
print(" 5 rows:",df.head())
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
# ...

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()
df=pd.DataFrame({
    'age':[200.00,38.8500,13.969007,18.000000,28.15000,36.00000,49.00000,70.00000],
    'annual income':[200.000,60.560000,26.264721,16.200000,41.50000,61.50000-0,78.000000,137.000000],
    'Spendingscore':[200.000,50.200000,25.823522,1.000000,34.750000,50.000000,73.000000,99.000000]

})
print (df)
print(df.isnull().sum())
mean=df.mean()
print(mean)
df=df.fillna(mean)
print(df)
print("missing value after replacing :",df.isnull().sum())
print(" 5 rows:",df.head())
# Out:
#           age  annual income  Spendingscore
# 0  200.000000     200.000000     200.000000
# 1   38.850000      60.560000      50.200000
# 2   13.969007      26.264721      25.823522
# 3   18.000000      16.200000       1.000000
# 4   28.150000      41.500000      34.750000
# 5   36.000000      61.500000      50.000000
# 6   49.000000      78.000000      73.000000
# 7   70.000000     137.000000      99.000000
# age              0
# annual income    0
# Spendingscore    0
# dtype: int64
# age              56.746126
# annual income    77.628090
# Spendingscore    66.721690
# dtype: float64
#           age  annual income  Spendingscore
# 0  200.000000     200.000000     200.000000
# 1   38.850000      60.560000      50.200000
# 2   13.969007      26.264721      25.823522
# 3   18.000000      16.200000       1.000000
# 4   28.150000      41.500000      34.750000
# 5   36.000000      61.500000      50.000000
# 6   49.000000      78.000000      73.000000
# ...

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()
df=pd.read_csv('Iris (1).csv')
print(df)
print(df.isnull().sum())
mean=df['PetalWidthCm'].mean()
print(mean)
df['PetalWidthCm'].fillna(mean)
print(df)
print("missing value after replacing :",df.isnull().sum())
print(" 5 rows:",df.head())
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...
